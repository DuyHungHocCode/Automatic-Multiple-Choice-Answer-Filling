# %%
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import requests as rq
from selenium import webdriver
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


options = ChromeOptions()
options.add_experimental_option("detach", True)
service = webdriver.ChromeService(executable_path = '/usr/bin/chromedriver')
driver = webdriver.Chrome(service=service, options = options)
driver.maximize_window()
driver.get("https://elearning.thanglong.edu.vn/login/index.php")
sleep(3)
print("truy cap trang web thanh cong")


login_but = driver.find_element(By.XPATH, "/html/body/div[5]/div/div/section/div/div/div/div/div/div/div[3]/div/div[2]/a")
login_but.click()
sleep(3)

email_input = driver.find_element(By.XPATH, "/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div[1]/div[3]/div/div/div/div[2]/div[2]/div/input[1]")
email_input.click()
email_input.send_keys("*******@thanglong.edu.vn")

Next_but = driver.find_element(By.XPATH, '/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div[1]/div[3]/div/div/div/div[4]/div/div/div/div/input')
Next_but.click()
sleep(3)

pass_input = driver.find_element(By.XPATH, '/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div/div[3]/div/div[2]/div/div[3]/div/div[2]/input')
pass_input.click()
pass_input.send_keys("**********")
sleep(3)

SignIn_but = driver.find_element(By.XPATH, '/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div/div[3]/div/div[2]/div/div[5]/div/div/div/div/input')
SignIn_but.click()


Stay_signed_in_No_but = driver.find_element(By.XPATH, '/html/body/div/form/div/div/div[2]/div[1]/div/div/div/div/div/div[3]/div/div[2]/div/div[3]/div[2]/div/div/div[1]/input')
Stay_signed_in_No_but.click()
sleep(3)


Enter_courses = driver.get('https://elearning.thanglong.edu.vn/course/view.php?id=19729')
Enter_week_reading_courses = driver.get('https://elearning.thanglong.edu.vn/mod/quiz/view.php?id=38897')

Enter_practice = driver.find_element(By.XPATH, '/html/body/div[2]/div[4]/div/div/div/section/div/div[1]/div[4]/div/div[1]/div/div/form/button')
Enter_practice.click()
# Out:
# truy cap trang web thanh cong

# %%
Correct_Answers_1 = []
Correct_Answers_1_to_5 = []
Correct_Answers_6_to_20 = []
Answers_1 = []
Answers_1_to_5 = []
Answers_6_to_20 = []

# %% [markdown]
# # FIRST RUN

# %%
for i in range(1,31):

    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    check = False
    
    for j in range(1,5):
        answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if answer_text in Correct_Answers_1:
            answer.click()
            check = True
            break
        
    if check == False:
        for j in range(1,5):
            answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
            answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
            
            if answer_text not in Answers_1:
                answer.click()
                Answers_1.append(answer_text)
                break
                
    
Next_page_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[2]/input')
Next_page_but.click()
    
for i in range(1,6):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
            if answer_text in Correct_Answers_1_to_5:
                answer_choice.click()
                check = True
                break
            
        if check == False:     
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_1_to_5:
                    answer_choice.click()
                    Answers_1_to_5.append(answer_text)
                    break        
            
Next_page_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[5]/input[2]')
Next_page_but_2.click()

for i in range(1,16):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
         
            if answer_text in Correct_Answers_6_to_20:
                answer_choice.click()
                check = True
                break
            
        if check == False:   
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_6_to_20:
                    answer_choice.click()
                    Answers_6_to_20.append(answer_text)
                    break
            
submit_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[16]/input[2]')
submit_but.click()

submit_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[8]/div/div/form/button')
submit_but_2.click()

submit_but_3 = driver.find_element(By.XPATH, '//input[@type="button"and @class="btn btn-primary" and @value="Submit all and finish"]')
submit_but_3.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[3], line 96
#      93 submit_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[8]/div/div/form/button')
#      94 submit_but_2.click()
# ---> 96 submit_but_3 = driver.find_element(By.XPATH, '//input[@type="button"and @class="btn btn-primary" and @value="Submit all and finish"]')
#      97 submit_but_3.click()
#
# File ~/Desktop/Automate-Project/venv/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %% [markdown]
# # FIRST RUN TO GET CORRECT ANSWER

# %%
for i in range(1,31):
    
    check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/div[{i}]').text
    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    for j in range(1,5):
        
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1:
            
            index = Answers_1.index(answer_text)
            
            if Answers_1[index] not in Correct_Answers_1:
                
                Correct_Answers_1.append(Answers_1[index])
                
                pass
                

for i in range(2,6):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1_to_5:
                
                index = Answers_1_to_5.index(answer_text)
                
                if Answers_1_to_5[index] not in Correct_Answers_1_to_5:
                    Correct_Answers_1_to_5.append(Answers_1_to_5[index])
     
for i in range(6,21):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_6_to_20:
                
                index = Answers_6_to_20.index(answer_text)
                
                if Answers_6_to_20[index] not in Correct_Answers_6_to_20:
                    Correct_Answers_6_to_20.append(Answers_6_to_20[index])
                    

Finish_review_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[2]/a')
Finish_review_but.click()

# %% [markdown]
# # 2

# %%
Answers_1_2 = []
Answers_1_to_5_2 = []
Answers_6_to_20_2 = []

for i in range(1,31):

    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    check = False
    
    for j in range(1,5):
        answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if answer_text in Correct_Answers_1:
            answer.click()
            check = True
            break
        
    if check == False:
        for j in range(1,5):
            answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
            answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
            
            if answer_text not in Answers_1:
                answer.click()
                Answers_1_2.append(answer_text)
                break
                
    
Next_page_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[2]/input')
Next_page_but.click()
    
for i in range(1,6):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
            if answer_text in Correct_Answers_1_to_5:
                answer_choice.click()
                check = True
                break
            
        if check == False:     
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_1_to_5:
                    answer_choice.click()
                    Answers_1_to_5_2.append(answer_text)
                    break        
            
Next_page_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[5]/input[2]')
Next_page_but_2.click()

for i in range(1,16):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
         
            if answer_text in Correct_Answers_6_to_20:
                answer_choice.click()
                check = True
                break
            
        if check == False:   
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_6_to_20:
                    answer_choice.click()
                    Answers_6_to_20_2.append(answer_text)
                    break
            
submit_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[16]/input[2]')
submit_but.click()

submit_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[8]/div/div/form/button')
submit_but_2.click()

submit_but_3 = driver.find_element(By.XPATH, '//input[@type="button"and @class="btn btn-primary" and @value="Submit all and finish"]')
submit_but_3.click()

# %% [markdown]
# # 2

# %%
for i in range(1,31):
    
    check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/div[{i}]').text
    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    for j in range(1,5):
        
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1_2:
            
            index = Answers_1_2.index(answer_text)
            
            if Answers_1_2[index] not in Correct_Answers_1:
                
                Correct_Answers_1.append(Answers_1_2[index])
                
                pass
                

for i in range(2,6):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1_to_5_2:
                
                index = Answers_1_to_5_2.index(answer_text)
                
                if Answers_1_to_5_2[index] not in Correct_Answers_1_to_5:
                    Correct_Answers_1_to_5.append(Answers_1_to_5_2[index])
     
for i in range(6,21):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_6_to_20_2:
                
                index = Answers_6_to_20_2.index(answer_text)
                
                if Answers_6_to_20_2[index] not in Correct_Answers_6_to_20:
                    Correct_Answers_6_to_20.append(Answers_6_to_20_2[index])
                    

Finish_review_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[2]/a')
Finish_review_but.click()

# %% [markdown]
# # 3

# %%
Answers_1_3 = []
Answers_1_to_5_3 = []
Answers_6_to_20_3 = []

for i in range(1,31):

    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    check = False
    
    for j in range(1,5):
        answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if answer_text in Correct_Answers_1:
            answer.click()
            check = True
            break
        
    if check == False:
        for j in range(1,5):
            answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
            answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
            
            if answer_text not in Answers_1 and answer_text not in Answers_1_2:
                answer.click()
                Answers_1_3.append(answer_text)
                break
                
    
Next_page_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[2]/input')
Next_page_but.click()
    
for i in range(1,6):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
            if answer_text in Correct_Answers_1_to_5:
                answer_choice.click()
                check = True
                break
            
        if check == False:     
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_1_to_5 and answer_text not in Answers_1_to_5_2:
                    answer_choice.click()
                    Answers_1_to_5_3.append(answer_text)
                    break        
            
Next_page_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[5]/input[2]')
Next_page_but_2.click()

for i in range(1,16):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
         
            if answer_text in Correct_Answers_6_to_20:
                answer_choice.click()
                check = True
                break
            
        if check == False:   
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_6_to_20 and answer_text not in Answers_6_to_20_2:
                    answer_choice.click()
                    Answers_6_to_20_3.append(answer_text)
                    break
            
submit_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[16]/input[2]')
submit_but.click()

submit_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[8]/div/div/form/button')
submit_but_2.click()

submit_but_3 = driver.find_element(By.XPATH, '//input[@type="button"and @class="btn btn-primary" and @value="Submit all and finish"]')
submit_but_3.click()

# %%
for i in range(1,31):
    
    check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/div[{i}]').text
    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    for j in range(1,5):
        
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1_3:
            
            index = Answers_1_3.index(answer_text)
            
            if Answers_1_3[index] not in Correct_Answers_1:
                
                Correct_Answers_1.append(Answers_1_3[index])
                
                pass
                

for i in range(2,6):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_1_to_5_3:
                
                index = Answers_1_to_5_3.index(answer_text)
                
                if Answers_1_to_5_3[index] not in Correct_Answers_1_to_5:
                    Correct_Answers_1_to_5.append(Answers_1_to_5_3[index])
     
for i in range(6,21):
    
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        
        check_correct = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/div[{j}]').text
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        for k in range(1,5):
            
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            
            if check_correct == 'Mark 1.00 out of 1.00' and answer_text in Answers_6_to_20_3:
                
                index = Answers_6_to_20_3.index(answer_text)
                
                if Answers_6_to_20_3[index] not in Correct_Answers_6_to_20:
                    Correct_Answers_6_to_20.append(Answers_6_to_20_3[index])
                    

Finish_review_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[2]/a')
Finish_review_but.click()

# %% [markdown]
# # 4

# %%
Answers_1_4 = []
Answers_1_to_5_4 = []
Answers_6_to_20_4 = []

for i in range(1,31):

    fieldset = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]')
    
    check = False
    
    for j in range(1,5):
        answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
        answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
        
        if answer_text in Correct_Answers_1:
            answer.click()
            check = True
            break
        
    if check == False:
        for j in range(1,5):
            answer = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/input')
            answer_text = fieldset.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[1]/div[2]/div/fieldset[{i}]/div[{j}]/label').text
            
            if answer_text not in Answers_1 and answer_text not in Answers_1_2 and answer_text not in Answers_1_3:
                answer.click()
                Answers_1_4.append(answer_text)
                break
                
    
Next_page_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[2]/input')
Next_page_but.click()
    
for i in range(1,6):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
            if answer_text in Correct_Answers_1_to_5:
                answer_choice.click()
                check = True
                break
            
        if check == False:     
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_1_to_5 and answer_text not in Answers_1_to_5_2 and answer_text not in Answers_1_to_5_3:
                    answer_choice.click()
                    Answers_1_to_5_4.append(answer_text)
                    break        
            
Next_page_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[5]/input[2]')
Next_page_but_2.click()

for i in range(1,16):
    question = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]')
    numberOfFieldset = question.find_elements(By.CLASS_NAME, 'answer')
    
    for j in range(1,len(numberOfFieldset)+1):
        answer = driver.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]')
        
        check = False
        
        for k in range(1,5):
            answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
            answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
        
         
            if answer_text in Correct_Answers_6_to_20:
                answer_choice.click()
                check = True
                break
            
        if check == False:   
            for k in range(1,5):
                answer_text = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/label').text
                answer_choice = answer.find_element(By.XPATH, f'/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[{i}]/div[2]/div/fieldset[{j}]/div[{k}]/input')
            
                if answer_text not in Answers_6_to_20 and answer_text not in Answers_6_to_20_2 and answer_text not in Answers_6_to_20_3:
                    answer_choice.click()
                    Answers_6_to_20_4.append(answer_text)
                    break
            
submit_but = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/form/div/div[16]/input[2]')
submit_but.click()

submit_but_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[5]/div/div/div/section/div/div[1]/div[4]/div/div[8]/div/div/form/button')
submit_but_2.click()

submit_but_3 = driver.find_element(By.XPATH, '//input[@type="button"and @class="btn btn-primary" and @value="Submit all and finish"]')
submit_but_3.click()
